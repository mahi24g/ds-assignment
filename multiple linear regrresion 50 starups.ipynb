# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
#Read the data
St = pd.read_csv(r"C:\Users\NAMO\Downloads/50_Startups.csv")
St.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
#
#    Unnamed: 5                                   Unnamed: 6
# 0         NaN                                          NaN
# 1         NaN                                          NaN
# 2         NaN                                          NaN
# 3         NaN  http://localhost:8888/notebooks/multi.ipynb
# 4         NaN                                          NaN

# %%
St.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
#  5   Unnamed: 5       0 non-null      float64
#  6   Unnamed: 6       1 non-null      object
# dtypes: float64(5), object(2)
# memory usage: 2.9+ KB

# %%
St.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit  \
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000
#
#        Unnamed: 5
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
#check for missing values
St.isna().sum()
# Out:
# R&D Spend           0
# Administration      0
# Marketing Spend     0
# State               0
# Profit              0
# Unnamed: 5         50
# Unnamed: 6         49
# dtype: int64

# %%
#check for duplicated records
St[St.duplicated()]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit, Unnamed: 5, Unnamed: 6]
# Index: []

# %%
# Rename the columns 

St1 = St.rename({'R&D Spend': 'RDS','Administration': 'ADM','Marketing Spend': 'MKS'}, axis=1)

# %%
St1.corr()
# Out:
#                  RDS       ADM       MKS    Profit  Unnamed: 5
# RDS         1.000000  0.241955  0.724248  0.972900         NaN
# ADM         0.241955  1.000000 -0.032154  0.200717         NaN
# MKS         0.724248 -0.032154  1.000000  0.747766         NaN
# Profit      0.972900  0.200717  0.747766  1.000000         NaN
# Unnamed: 5       NaN       NaN       NaN       NaN         NaN

# %%
#Scatterplot between variables along with histograms
sns.set_style(style='darkgrid')
sns.pairplot(St1)

# %%
#MODEL BUILDING
model = smf.ols('Profit~RDS+ADM+MKS',data=St1).fit()

# %%
#MODEL TESTING
#Co-efficient of model
model.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADM             -0.026816
# MKS              0.027228
# dtype: float64

# %%
# Summary of model
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):           4.53e-30
# Time:                        21:41:34   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# RDS            0.8057      0.045     17.846      0.000       0.715       0.897
# ADM           -0.0268      0.051     -0.526      0.602      -0.130       0.076
# MKS            0.0272      0.016      1.655      0.105      -0.006       0.060
# ==============================================================================
# Omnibus:                       14.838   Durbin-Watson:                   1.282
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.442
# Skew:                          -0.949   Prob(JB):                     2.21e-05
# Kurtosis:                       5.586   Cond. No.                     1.40e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Since the p value for Administration and Marketing Spend is > 0.05 build simple linear regression and multi linear regression models  to see insignificant variables

# %%
slr_adm = smf.ols('Profit~ADM',data=St1).fit()

# %%
slr_adm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):              0.162
# Time:                        21:41:39   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.697e+04   2.53e+04      3.040      0.004    2.61e+04    1.28e+05
# ADM            0.2887      0.203      1.419      0.162      -0.120       0.698
# ==============================================================================
# Omnibus:                        0.126   Durbin-Watson:                   0.099
# Prob(Omnibus):                  0.939   Jarque-Bera (JB):                0.110
# Skew:                           0.093   Prob(JB):                        0.947
# Kurtosis:                       2.866   Cond. No.                     5.59e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.59e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Build a simple linear model to check the column Marketing

slr_mar = smf.ols('Profit~MKS',data=St1).fit()

# %%
slr_mar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):           4.38e-10
# Time:                        21:41:40   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept       6e+04   7684.530      7.808      0.000    4.46e+04    7.55e+04
# MKS            0.2465      0.032      7.803      0.000       0.183       0.310
# ==============================================================================
# Omnibus:                        4.420   Durbin-Watson:                   1.178
# Prob(Omnibus):                  0.110   Jarque-Bera (JB):                3.882
# Skew:                          -0.336   Prob(JB):                        0.144
# Kurtosis:                       4.188   Cond. No.                     4.89e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.89e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Build the Multi Linear regression model of Adminstration and Marketing together to check for collinearity problem

slr_AM = smf.ols('Profit~ADM+MKS',data=St1).fit()

# %%
slr_AM.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     36.71
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):           2.50e-10
# Time:                        21:41:42   Log-Likelihood:                -577.13
# No. Observations:                  50   AIC:                             1160.
# Df Residuals:                      47   BIC:                             1166.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.022e+04   1.77e+04      1.143      0.259   -1.54e+04    5.58e+04
# ADM            0.3237      0.131      2.468      0.017       0.060       0.588
# MKS            0.2488      0.030      8.281      0.000       0.188       0.309
# ==============================================================================
# Omnibus:                        6.584   Durbin-Watson:                   1.279
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):                6.524
# Skew:                          -0.512   Prob(JB):                       0.0383
# Kurtosis:                       4.443   Cond. No.                     1.30e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# When we build the model together both of the columns have significant p value
#
# Model Validation Techniques Two Techniques
#
# 1) Collinearity Check - VIF
#
# 2) Residual Analysis
#
# Calculating Variance Inflation Factor (VIF) = 1/1-r^2#

# %%
rsq_rds = smf.ols('RDS~ADM+MKS',data=St1).fit().rsquared  
vif_rds = 1/(1-rsq_rds) 
vif_rds
# Out:
# 2.4689030699947017

# %%
rsq_adm = smf.ols('ADM~RDS+MKS',data=St1).fit().rsquared  
vif_adm = 1/(1-rsq_adm) 
vif_adm
# Out:
# 1.1750910070550455

# %%
rsq_mks = smf.ols('MKS~RDS+ADM',data=St1).fit().rsquared  
vif_mks = 1/(1-rsq_mks) 
vif_mks
# Out:
# 2.326773290530878

# %%
# Storing vif values in a data frame
d1 = {'Variables':['RDS','ADM','MKS'],'VIF':[vif_rds,vif_adm,vif_mks]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#   Variables       VIF
# 0       RDS  2.468903
# 1       ADM  1.175091
# 2       MKS  2.326773

# %% [markdown]
# Since No value of VIF is greater than 20 , we can say that there is no collinearity problem. So we shall consider all columns for building the model

# %% [markdown]
# # Residual Analysis
# # Test for Normality of Residuals (Q-Q Plot)

# %%
import statsmodels.api as sm
sns.set_style(style='darkgrid')
qqplot=sm.qqplot(model.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-10000))
# Out:
# [array([14, 15, 48, 49], dtype=int64)]

# %% [markdown]
# Residual Plot for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()  #User Defined Function Z = (x-mu)/sigma

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# Residual Vs Regressors

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "RDS", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "ADM", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "MKS", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion Diagnostics
# # Detecting Influuencers / Outliers
# # Cooks Distance

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
sns.set_style(style='darkgrid')
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(St1)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %% [markdown]
# There are no datapoints whose value is greater than 0.5
#
# # High Influence Plots

# %%
fig,ax=plt.subplots(figsize=(15,10))
fig=influence_plot(model,ax = ax)

# %%
k = St1.shape[1]     # k = no.of features/columns & n = no. of datapoints
n = St1.shape[0] 
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.48

# %%
St1[St1.index.isin([49])]
# Out:
#     RDS       ADM       MKS       State   Profit  Unnamed: 5 Unnamed: 6
# 49  0.0  116983.8  45173.06  California  14681.4         NaN        NaN

# %% [markdown]
# # Improving the model

# %%
#Discard the data points which are influencers and reasign the row number (reset_index())
St2=St1.copy()
St2
# Out:
#           RDS        ADM        MKS       State     Profit  Unnamed: 5  \
# 0   165349.20  136897.80  471784.10    New York  192261.83         NaN
# 1   162597.70  151377.59  443898.53  California  191792.06         NaN
# 2   153441.51  101145.55  407934.54     Florida  191050.39         NaN
# 3   144372.41  118671.85  383199.62    New York  182901.99         NaN
# 4   142107.34   91391.77  366168.42     Florida  166187.94         NaN
# 5   131876.90   99814.71  362861.36    New York  156991.12         NaN
# 6   134615.46  147198.87  127716.82  California  156122.51         NaN
# 7   130298.13  145530.06  323876.68     Florida  155752.60         NaN
# 8   120542.52  148718.95  311613.29    New York  152211.77         NaN
# 9   123334.88  108679.17  304981.62  California  149759.96         NaN
# 10  101913.08  110594.11  229160.95     Florida  146121.95         NaN
# 11  100671.96   91790.61  249744.55  California  144259.40         NaN
# 12   93863.75  127320.38  249839.44     Florida  141585.52         NaN
# 13   91992.39  135495.07  252664.93  California  134307.35         NaN
# 14  119943.24  156547.42  256512.92     Florida  132602.65         NaN
# 15  114523.61  122616.84  261776.23    New York  129917.04         NaN
# 16   78013.11  121597.55  264346.06  California  126992.93         NaN
# 17   94657.16  145077.58  282574.31    New York  125370.37         NaN
# 18   91749.16  114175.79  294919.57     Florida  124266.90         NaN
# 19   86419.70  153514.11       0.00    New York  122776.86         NaN
# 20   76253.86  113867.30  298664.47  California  118474.03         NaN
# 21   78389.47  153773.43  299737.29    New York  111313.02         NaN
# 22   73994.56  122782.75  303319.26     Florida  110352.25         NaN
# 23   67532.53  105751.03  304768.73     Florida  108733.99         NaN
# 24   77044.01   99281.34  140574.81    New York  108552.04         NaN
# 25   64664.71  139553.16  137962.62  California  107404.34         NaN
# 26   75328.87  144135.98  134050.07     Florida  105733.54         NaN
# 27   72107.60  127864.55  353183.81    New York  105008.31         NaN
# 28   66051.52  182645.56  118148.20     Florida  103282.38         NaN
# 29   65605.48  153032.06  107138.38    New York  101004.64         NaN
# 30   61994.48  115641.28   91131.24     Florida   99937.59         NaN
# 31   61136.38  152701.92   88218.23    New York   97483.56         NaN
# 32   63408.86  129219.61   46085.25  California   97427.84         NaN
# 33   55493.95  103057.49  214634.81     Florida   96778.92         NaN
# 34   46426.07  157693.92  210797.67  California   96712.80         NaN
# 35   46014.02   85047.44  205517.64    New York   96479.51         NaN
# 36   28663.76  127056.21  201126.82     Florida   90708.19         NaN
# 37   44069.95   51283.14  197029.42  California   89949.14         NaN
# 38   20229.59   65947.93  185265.10    New York   81229.06         NaN
# 39   38558.51   82982.09  174999.30  California   81005.76         NaN
# 40   28754.33  118546.05  172795.67  California   78239.91         NaN
# 41   27892.92   84710.77  164470.71     Florida   77798.83         NaN
# 42   23640.93   96189.63  148001.11  California   71498.49         NaN
# 43   15505.73  127382.30   35534.17    New York   69758.98         NaN
# 44   22177.74  154806.14   28334.72  California   65200.33         NaN
# 45    1000.23  124153.04    1903.93    New York   64926.08         NaN
# 46    1315.46  115816.21  297114.46     Florida   49490.75         NaN
# 47       0.00  135426.92       0.00  California   42559.73         NaN
# 48     542.05   51743.15       0.00    New York   35673.41         NaN
# 49       0.00  116983.80   45173.06  California   14681.40         NaN
#
#                                      Unnamed: 6
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3   http://localhost:8888/notebooks/multi.ipynb
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                          NaN
# 31                                          NaN
# 32                                          NaN
# 33                                          NaN
# 34                                          NaN
# 35                                          NaN
# 36                                          NaN
# 37                                          NaN
# 38                                          NaN
# 39                                          NaN
# 40                                          NaN
# 41                                          NaN
# 42                                          NaN
# 43                                          NaN
# 44                                          NaN
# 45                                          NaN
# 46                                          NaN
# 47                                          NaN
# 48                                          NaN
# 49                                          NaN

# %% [markdown]
# # Model Deletion Diagoniostics & Final Model

# %%
Final_Model = smf.ols('Profit~RDS+ADM+MKS',data=St2).fit()

# %%
Final_Model .summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):           4.53e-30
# Time:                        21:42:31   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# RDS            0.8057      0.045     17.846      0.000       0.715       0.897
# ADM           -0.0268      0.051     -0.526      0.602      -0.130       0.076
# MKS            0.0272      0.016      1.655      0.105      -0.006       0.060
# ==============================================================================
# Omnibus:                       14.838   Durbin-Watson:                   1.282
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.442
# Skew:                          -0.949   Prob(JB):                     2.21e-05
# Kurtosis:                       5.586   Cond. No.                     1.40e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Thus the Accuracy of the model has improved to 96.1%
#
# # Model Predictions

# %%
#New data for prediction
new_data=pd.DataFrame({'RDS':78000,'ADM':127864.55,"MKS":249839.44},index=[1])
new_data
# Out:
#      RDS        ADM        MKS
# 1  78000  127864.55  249839.44

# %%
# Manual prediction
Final_Model.predict(new_data)
# Out:
# 1    116341.799614
# dtype: float64

# %%
#Automatic Prediction 
pred_y = Final_Model.predict(St2)
pred_y
# Out:
# 0     192521.252890
# 1     189156.768232
# 2     182147.279096
# 3     173696.700026
# 4     172139.514183
# 5     163580.780571
# 6     158114.096669
# 7     160021.363048
# 8     151741.699699
# 9     154884.684110
# 10    135509.016367
# 11    135573.712961
# 12    129138.054182
# 13    127487.991663
# 14    149548.646335
# 15    146235.159985
# 16    116915.405401
# 17    130192.447208
# 18    129014.226806
# 19    115635.216367
# 20    116639.669231
# 21    117319.451640
# 22    114706.981717
# 23    109996.615221
# 24    113362.966113
# 25    102237.725065
# 26    110600.575350
# 27    114408.071457
# 28    101660.026005
# 29    101794.983452
# 30     99452.372936
# 31     97687.856276
# 32     99001.328985
# 33     97915.007805
# 34     89039.273741
# 35     90511.599568
# 36     75286.174585
# 37     89619.537708
# 38     69697.430648
# 39     83729.011977
# 40     74815.953991
# 41     74802.556239
# 42     70620.411821
# 43     60167.039963
# 44     64611.354916
# 45     47650.649687
# 46     56166.206853
# 47     46490.588983
# 48     49171.388158
# 49     48215.134111
# dtype: float64

# %% [markdown]
#  ## Table Containing R square values

# %%
Prepared_Models=pd.DataFrame(['Model','Final_Model'],index=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 Prepared_Models=pd.DataFrame(['Model','Final_Model'],index=1)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:737, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     729         mgr = arrays_to_mgr(
#     730             arrays,
#     731             columns,
#    (...)
#     734             typ=manager,
#     735         )
#     736     else:
# --> 737         mgr = ndarray_to_mgr(
#     738             data,
#     739             index,
#     740             columns,
#     741             dtype=dtype,
#     742             copy=copy,
#     743             typ=manager,
#     744         )
#     745 else:
#     746     mgr = dict_to_mgr(
#     747         {},
#     748         index,
#    (...)
#     751         typ=manager,
#     752     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:347, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     344     values = values.reshape(shape)
#     346 # _prep_ndarray ensures that values.ndim == 2 at this point
# --> 347 index, columns = _get_axes(
#     348     values.shape[0], values.shape[1], index=index, columns=columns
#     349 )
#     351 _check_values_indices_shape_match(values, index, columns)
#     353 if typ == "array":
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:756, in _get_axes(N, K, index, columns)
#     754     index = default_index(N)
#     755 else:
# --> 756     index = ensure_index(index)
#     758 if columns is None:
#     759     columns = default_index(K)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:7043, in ensure_index(index_like, copy)
#    7041         return Index._with_infer(index_like, copy=copy, tupleize_cols=False)
#    7042 else:
# -> 7043     return Index._with_infer(index_like, copy=copy)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:680, in Index._with_infer(cls, *args, **kwargs)
#     678 with warnings.catch_warnings():
#     679     warnings.filterwarnings("ignore", ".*the Index constructor", FutureWarning)
# --> 680     result = cls(*args, **kwargs)
#     682 if result.dtype == _dtype_obj and not result._is_multi:
#     683     # error: Argument 1 to "maybe_convert_objects" has incompatible type
#     684     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected
#     685     # "ndarray[Any, Any]"
#     686     values = lib.maybe_convert_objects(result._values)  # type: ignore[arg-type]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:508, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     505     return klass._simple_new(arr, name)
#     507 elif is_scalar(data):
# --> 508     raise cls._scalar_data_error(data)
#     509 elif hasattr(data, "__array__"):
#     510     return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, 1 was passed
